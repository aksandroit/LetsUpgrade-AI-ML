# %%
import pandas as pd 
from scipy.stats import pointbiserialr
from scipy.stats import pearsonr
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('general_data.csv')

# %%
df
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
# 4409   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
df.shape
# Out:
# (4410, 24)

# %%
df.Attrition.replace(to_replace = ('No','Yes'),value = (0,1),inplace = True)

# %%
stats, p = pearsonr(df.Attrition, df.Age)
print(stats, p)
# Out:
# -0.15920500686577987 1.996801615886744e-26

# %% [markdown]
# # Hypothesis 1
#
# null hypothesis (H0)  = Age and attrition have no correlation .
#
# alternate hypothesis (H1) =  Age and attrition have a correlation between them .
#
# r = -0.15920500686577965
#
# p = 1.996801615886744e-26
#
# r is negative so there is a negative relation between Age and attrition
#
# and as p <0.05 so null hypothesis (H0) is rejected and we find that there is a negative correlation between attrition and age

# %%
stats, p = pearsonr(df.Attrition, df.DistanceFromHome)
print(stats, p)
# Out:
# -0.009730141010179692 0.5182860428050771

# %% [markdown]
# # Hypothesis 2
# null hypothesis (H0)  = Attrition  and distance from home  have no correlation .
#
# alternate hypothesis (H1) =  Attrition  and distance from home have a correlation between them .
#
# r = -0.00973014101017967
#
# p = 0.5182860428050771
#
# Here p is greater than 0.05 hence we accept the null hypothesis (H0) that there is no realtion between attrtion and distance from home

# %%
stats, p = pearsonr(df.Attrition, df.MonthlyIncome)
print(stats, p)
# Out:
# -0.031176281698115087 0.03842748490600132

# %% [markdown]
# # Hypothesis 3
# null hypothesis (H0)  = Attrition  and monthly income   have no correlation .
#
# alternate hypothesis (H1) =  Attrition  and monthly income have a correlation between them .
#
# r = -0.03117628169811501
#
# p = 0.03842748490600132
#
# As p is lesser than .05 we reject null hypothesis (H0) and conclude that there is a significant relation between TRRITION AND MONTHLY INCOME.
#
# r is -.0311 so we see there is negative relation between the two

# %%
stats, p = pearsonr(df.Attrition, df.PercentSalaryHike)
print(stats, p)
# Out:
# 0.03253259489105355 0.030743386433355353

# %% [markdown]
# # Hypothesis 4
# null hypothesis (H0)  = Attrition and salary hike percentage have no correlation .
#
# alternate hypothesis (H1) =  Attrition and salary hike percentage have a correlation between them .
#
# r = 0.03253259489105349
#
# p = 0.030743386433355353
#
# As p is lesser than .05 we reject null hypothesis (H0) and conclude that there is a significant relation between Attrition and salary hike percent .
#
# r is 0.032 so we see there is positive  relation between the two

# %%
stats, p = pearsonr(df.Attrition, df.TrainingTimesLastYear)
print(stats, p)
# Out:
# -0.04943057624425508 0.0010247061915362814

# %% [markdown]
# # Hypothesis 5
# null hypothesis (H0)  = Attrition and TrainingTimesLastYear have no correlation .
#
# alternate hypothesis (H1) =  Attrition and TrainingTimesLastYear have a correlation between them .
#
# r = -0.049430576244255
#
# p = 0.0010247061915365072
#
# As p is lesser than .05 we reject null hypothesis (H0) and conclude that there is a significant relation between Attrition and TrainingTimesLastYear .
#
# r is -0.049 so we see there is negative relation between the two

# %%
stats, p = pearsonr(df.Attrition, df.YearsAtCompany)
print(stats, p)
# Out:
# -0.13439221398997758 3.1638831224870065e-19

# %% [markdown]
# # Hypothesis 6
# null hypothesis (H0)  = Attrition and YearsAtCompany have no correlation .
#
# alternate hypothesis (H1) =  Attrition and YearsAtCompany have a correlation between them .
#
# r = -0.1343922139899772
#
# p = 3.1638831224877484e-19
#
# As p is lesser than .05 we reject null hypothesis (H0) and conclude that there is a significant relation between Attrition and YearsAtCompany .
#
# r is -0.134 so we see there is negative relation between the two

# %%
stats, p = pearsonr(df.Attrition, df.YearsSinceLastPromotion)
print(stats, p)
# Out:
# -0.03301877514258443 0.028330336189402967

# %% [markdown]
# # Hypothesis 7
# null hypothesis (H0)  = Attrition and YearsSinceLastPromotion have no correlation .
#
# alternate hypothesis (H1) =  Attrition and YearsSinceLastPromotion have a correlation between them .
#
# r = -0.03301877514258433
#
# p = 0.028330336189396753
#
# As p is lesser than .05 we reject null hypothesis (H0) and conclude that there is a significant relation between Attrition and YearsSinceLastPromotion .
#
# r is -0.033 so we see there is negative relation between the two

# %%
stats, p = pearsonr(df.Attrition, df.YearsWithCurrManager)
print(stats, p)
# Out:
# -0.15619931590162844 1.7339322652900218e-25

# %% [markdown]
# # Hypothesis 8
# null hypothesis (H0)  = Attrition and YearsWithCurrManager have no correlation .
#
# alternate hypothesis (H1) =  Attrition and YearsWithCurrManager have a correlation between them .
#
# -0.15619931590162847
#
# 1.7339322652896276e-25
#
# As p is lesser than .05 we reject null hypothesis (H0) and conclude that there is a significant relation between Attrition and YearsWithCurrManager.
#
# r is -0.156 so we see there is negative relation between the two

# %%
import numpy as np
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
df.isnull()
# Out:
#         Age  Attrition  BusinessTravel  Department  DistanceFromHome  \
# 0     False      False           False       False             False
# 1     False      False           False       False             False
# 2     False      False           False       False             False
# 3     False      False           False       False             False
# 4     False      False           False       False             False
# ...     ...        ...             ...         ...               ...
# 4405  False      False           False       False             False
# 4406  False      False           False       False             False
# 4407  False      False           False       False             False
# 4408  False      False           False       False             False
# 4409  False      False           False       False             False
#
#       Education  EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4405    False
# 4406    False
# 4407    False
# 4408    False
# 4409    False
# Length: 4410, dtype: bool

# %%
df.drop_duplicates()
# Out:
#       Age  Attrition     BusinessTravel              Department  \
# 0      51          0      Travel_Rarely                   Sales
# 1      31          1  Travel_Frequently  Research & Development
# 2      32          0  Travel_Frequently  Research & Development
# 3      38          0         Non-Travel  Research & Development
# 4      32          0      Travel_Rarely  Research & Development
# ...   ...        ...                ...                     ...
# 4405   42          0      Travel_Rarely  Research & Development
# 4406   29          0      Travel_Rarely  Research & Development
# 4407   25          0      Travel_Rarely  Research & Development
# 4408   42          0      Travel_Rarely                   Sales
# 4409   40          0      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
df2=df[['Age','DistanceFromHome','Education','MonthlyIncome', 'NumCompaniesWorked',
             'PercentSalaryHike','TotalWorkingYears', 'TrainingTimesLastYear', 
             'YearsAtCompany','YearsSinceLastPromotion', 'YearsWithCurrManager']].describe()
df2
# Out:
#                Age  DistanceFromHome    Education  MonthlyIncome  \
# count  4410.000000       4410.000000  4410.000000    4410.000000
# mean     36.923810          9.192517     2.912925   65029.312925
# std       9.133301          8.105026     1.023933   47068.888559
# min      18.000000          1.000000     1.000000   10090.000000
# 25%      30.000000          2.000000     2.000000   29110.000000
# 50%      36.000000          7.000000     3.000000   49190.000000
# 75%      43.000000         14.000000     4.000000   83800.000000
# max      60.000000         29.000000     5.000000  199990.000000
#
#        NumCompaniesWorked  PercentSalaryHike  TotalWorkingYears  \
# count         4391.000000        4410.000000        4401.000000
# mean             2.694830          15.209524          11.279936
# std              2.498887           3.659108           7.782222
# min              0.000000          11.000000           0.000000
# ...

# %%
df2=df[['Age','DistanceFromHome','Education','MonthlyIncome', 'NumCompaniesWorked', 
       'PercentSalaryHike','TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany',
       'YearsSinceLastPromotion', 'YearsWithCurrManager']].median()
df2
# Out:
# Age                           36.0
# DistanceFromHome               7.0
# Education                      3.0
# MonthlyIncome              49190.0
# NumCompaniesWorked             2.0
# PercentSalaryHike             14.0
# TotalWorkingYears             10.0
# TrainingTimesLastYear          3.0
# YearsAtCompany                 5.0
# YearsSinceLastPromotion        1.0
# YearsWithCurrManager           3.0
# dtype: float64

# %%
df
# Out:
#       Age  Attrition     BusinessTravel              Department  \
# 0      51          0      Travel_Rarely                   Sales
# 1      31          1  Travel_Frequently  Research & Development
# 2      32          0  Travel_Frequently  Research & Development
# 3      38          0         Non-Travel  Research & Development
# 4      32          0      Travel_Rarely  Research & Development
# ...   ...        ...                ...                     ...
# 4405   42          0      Travel_Rarely  Research & Development
# 4406   29          0      Travel_Rarely  Research & Development
# 4407   25          0      Travel_Rarely  Research & Development
# 4408   42          0      Travel_Rarely                   Sales
# 4409   40          0      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
df2
# Out:
# Age                           36.0
# DistanceFromHome               7.0
# Education                      3.0
# MonthlyIncome              49190.0
# NumCompaniesWorked             2.0
# PercentSalaryHike             14.0
# TotalWorkingYears             10.0
# TrainingTimesLastYear          3.0
# YearsAtCompany                 5.0
# YearsSinceLastPromotion        1.0
# YearsWithCurrManager           3.0
# dtype: float64

# %%
df2=df[['Age','DistanceFromHome','Education','MonthlyIncome', 'NumCompaniesWorked', 
                   'PercentSalaryHike','TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany',
                   'YearsSinceLastPromotion', 'YearsWithCurrManager']].mode()
df2
# Out:
#    Age  DistanceFromHome  Education  MonthlyIncome  NumCompaniesWorked  \
# 0   35                 2          3          23420                 1.0
#
#    PercentSalaryHike  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 11               10.0                      2
#
#    YearsAtCompany  YearsSinceLastPromotion  YearsWithCurrManager
# 0               5                        0                     2

# %%
df2=df[['Age','DistanceFromHome','Education','MonthlyIncome', 'NumCompaniesWorked', 
                   'PercentSalaryHike','TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany',
                   'YearsSinceLastPromotion', 'YearsWithCurrManager']].var()
df2
# Out:
# Age                        8.341719e+01
# DistanceFromHome           6.569144e+01
# Education                  1.048438e+00
# MonthlyIncome              2.215480e+09
# NumCompaniesWorked         6.244436e+00
# PercentSalaryHike          1.338907e+01
# TotalWorkingYears          6.056298e+01
# TrainingTimesLastYear      1.661465e+00
# YearsAtCompany             3.751728e+01
# YearsSinceLastPromotion    1.037935e+01
# YearsWithCurrManager       1.272582e+01
# dtype: float64

# %%
df2=df[['Age','DistanceFromHome','Education','MonthlyIncome', 'NumCompaniesWorked',
                   'PercentSalaryHike','TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany',
                   'YearsSinceLastPromotion', 'YearsWithCurrManager']].skew()
df2
# Out:
# Age                        0.413005
# DistanceFromHome           0.957466
# Education                 -0.289484
# MonthlyIncome              1.368884
# NumCompaniesWorked         1.026767
# PercentSalaryHike          0.820569
# TotalWorkingYears          1.116832
# TrainingTimesLastYear      0.552748
# YearsAtCompany             1.763328
# YearsSinceLastPromotion    1.982939
# YearsWithCurrManager       0.832884
# dtype: float64

# %%
df2=df[['Age','DistanceFromHome','Education','MonthlyIncome', 'NumCompaniesWorked',
                   'PercentSalaryHike','TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany',
                   'YearsSinceLastPromotion', 'YearsWithCurrManager']].kurt()
df2
# Out:
# Age                       -0.405951
# DistanceFromHome          -0.227045
# Education                 -0.560569
# MonthlyIncome              1.000232
# NumCompaniesWorked         0.007287
# PercentSalaryHike         -0.302638
# TotalWorkingYears          0.912936
# TrainingTimesLastYear      0.491149
# YearsAtCompany             3.923864
# YearsSinceLastPromotion    3.601761
# YearsWithCurrManager       0.167949
# dtype: float64

# %%
#checking boxplot:

box_plot=df.Age
plt.boxplot(box_plot)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x27a42d9f548>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x27a42d9ff08>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x27a42b67dc8>],
#  'medians': [<matplotlib.lines.Line2D at 0x27a42dabb48>],
#  'fliers': [<matplotlib.lines.Line2D at 0x27a42dabf48>],
#  'means': []}

# %% [markdown]
# Age is normally distributed without any outliers

# %%
box_plot=df.MonthlyIncome
plt.boxplot(box_plot)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x27a4307d548>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x27a4307df08>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x27a43075dc8>],
#  'medians': [<matplotlib.lines.Line2D at 0x27a43084b48>],
#  'fliers': [<matplotlib.lines.Line2D at 0x27a43084f48>],
#  'means': []}

# %% [markdown]
# Monthly Income is Right skewed with several outliers

# %%
box_plot=df.YearsAtCompany
plt.boxplot(box_plot)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x27a430eedc8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x27a430f3d88>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x27a430ee408>],
#  'medians': [<matplotlib.lines.Line2D at 0x27a430f7d08>],
#  'fliers': [<matplotlib.lines.Line2D at 0x27a430f7e08>],
#  'means': []}

# %% [markdown]
# Years at company is also Right Skewed with several outliers observed.

# %% [markdown]
# ## Exploratory Data Analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
df
# Out:
#       Age  Attrition     BusinessTravel              Department  \
# 0      51          0      Travel_Rarely                   Sales
# 1      31          1  Travel_Frequently  Research & Development
# 2      32          0  Travel_Frequently  Research & Development
# 3      38          0         Non-Travel  Research & Development
# 4      32          0      Travel_Rarely  Research & Development
# ...   ...        ...                ...                     ...
# 4405   42          0      Travel_Rarely  Research & Development
# 4406   29          0      Travel_Rarely  Research & Development
# 4407   25          0      Travel_Rarely  Research & Development
# 4408   42          0      Travel_Rarely                   Sales
# 4409   40          0      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
df.describe(include=[np.object])
# Out:
#        BusinessTravel              Department EducationField Gender  \
# count            4410                    4410           4410   4410
# unique              3                       3              6      2
# top     Travel_Rarely  Research & Development  Life Sciences   Male
# freq             3129                    2883           1818   2646
#
#                 JobRole MaritalStatus Over18
# count              4410          4410   4410
# unique                9             3      1
# top     Sales Executive       Married      Y
# freq                978          2019   4410

# %%
attrition_freq = df[['Attrition']].apply(lambda x: x.value_counts())
attrition_freq['frequency_percent'] = round((100 * attrition_freq / attrition_freq.sum()),2)

print(attrition_freq)

# Attrition distribution bar plot
plot = attrition_freq[['frequency_percent']].plot(kind="bar");
plot.set_title("Attrition Distribution", fontsize=20);
plot.grid(color='lightgray', alpha=0.5);
# Out:
#    Attrition  frequency_percent
# 0       3699              83.88
# 1        711              16.12

# %% [markdown]
# Just by a quick inspection of the counts of the number of 'Yes' and 'No' in the target variable tells us that there is quite a large skew in target variable.
# Therefore we have to keep in mind that there is quite a big imbalance in our target variable. Many statistical techniques have been put forth to treat imbalances in data (oversampling or undersampling).
# In this notebook, I will use an oversampling technique known as SMOTE to treat this imbalance.
# We will see the prediction model with and without SMOTE treatment for imbalance class issue

# %% [markdown]
# ## Exploratory Data Analysis

# %%
null_feat_df = pd.DataFrame()
null_feat_df['Null Count'] = df.isnull().sum().sort_values(ascending=False)
null_feat_df['Null Pct'] = null_feat_df['Null Count'] / float(len(df))

null_feat_df = null_feat_df[null_feat_df['Null Pct'] > 0]

total_null_feats = null_feat_df.shape[0]
null_feat_names = null_feat_df.index
print('Total number of features having null values: ', total_null_feats)
del null_feat_df
# Out:
# Total number of features having null values:  2

# %%
df1=df.dropna(axis=0) #Drop NA values from columns
df1
# Out:
#       Age  Attrition     BusinessTravel              Department  \
# 0      51          0      Travel_Rarely                   Sales
# 1      31          1  Travel_Frequently  Research & Development
# 2      32          0  Travel_Frequently  Research & Development
# 3      38          0         Non-Travel  Research & Development
# 4      32          0      Travel_Rarely  Research & Development
# ...   ...        ...                ...                     ...
# 4404   29          0      Travel_Rarely                   Sales
# 4405   42          0      Travel_Rarely  Research & Development
# 4406   29          0      Travel_Rarely  Research & Development
# 4407   25          0      Travel_Rarely  Research & Development
# 4408   42          0      Travel_Rarely                   Sales
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
df1.shape
# Out:
# (4382, 24)

# %%
null_feat_df = pd.DataFrame()
null_feat_df['Null Count'] = df1.isnull().sum().sort_values(ascending=False)
null_feat_df['Null Pct'] = null_feat_df['Null Count'] / float(len(df1))

null_feat_df = null_feat_df[null_feat_df['Null Pct'] > 0]

total_null_feats = null_feat_df.shape[0]
null_feat_names = null_feat_df.index
print('Total number of features having null values: ', total_null_feats)
del null_feat_df
# Out:
# Total number of features having null values:  0

# %%
#categorical Features
df2 = df1.copy() # Copy cleaned dataset for EDA & feature changes

# Let's add 2 features for EDA: Employee left and not left
df2['Attrition_Yes'] = df2['Attrition'].map({'Yes':1, 'No':0}) # 1 means Employee Left
df2['Attrition_No'] =df2['Attrition'].map({'Yes':0, 'No':1}) # 1 means Employee didnt leave

# Let's look into the new dataset and identify features for which plots needs to be build for categorical features
df2.head()
# Out:
#    Age  Attrition     BusinessTravel              Department  \
# 0   51          0      Travel_Rarely                   Sales
# 1   31          1  Travel_Frequently  Research & Development
# 2   32          0  Travel_Frequently  Research & Development
# 3   38          0         Non-Travel  Research & Development
# 4   32          0      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                 6          2  Life Sciences              1           1
# 1                10          1  Life Sciences              1           2
# 2                17          4          Other              1           3
# 3                 2          5  Life Sciences              1           4
# 4                10          1        Medical              1           5
#
#    Gender  ...  PercentSalaryHike StandardHours StockOptionLevel  \
# 0  Female  ...                 11             8                0
# ...

# %%
cat_col_names = df2.select_dtypes(include=[np.object]).columns.tolist() # Get categorical feature names
cat_col_names
# Out:
# ['BusinessTravel',
#  'Department',
#  'EducationField',
#  'Gender',
#  'JobRole',
#  'MaritalStatus',
#  'Over18']

# %%
df2.dtypes
# Out:
# Age                          int64
# Attrition                    int64
# BusinessTravel              object
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeID                   int64
# Gender                      object
# JobLevel                     int64
# JobRole                     object
# MaritalStatus               object
# MonthlyIncome                int64
# NumCompaniesWorked         float64
# Over18                      object
# PercentSalaryHike            int64
# StandardHours                int64
# StockOptionLevel             int64
# TotalWorkingYears          float64
# TrainingTimesLastYear        int64
# YearsAtCompany               int64
# YearsSinceLastPromotion      int64
# YearsWithCurrManager         int64
# Attrition_Yes              float64
# Attrition_No               float64
# dtype: object

# %%
df2= df.replace(['Yes', 'No'], [1,0]) #Making a data frame with encoded Attrition column.
df2.head()
df3= df2.copy()

# %%
from sklearn.preprocessing import LabelEncoder
#Stats packages
from scipy.stats import pointbiserialr
from scipy.stats import pearsonr, chi2_contingency, wilcoxon, friedmanchisquare, mannwhitneyu, kruskal, chi2_contingency
from scipy.stats import ttest_1samp, ttest_rel, ttest_ind


le=LabelEncoder()  #Encoding some categorical Variables
df3['BusinessTravel']=le.fit_transform(df3.BusinessTravel)
df3['DistanceFromHome']=le.fit_transform(df3.DistanceFromHome)

df3['Gender']=le.fit_transform(df3.Gender)

df3['MaritalStatus']=le.fit_transform(df3.MaritalStatus)

# %%
#These fields does not add value, hence removed
df2= df2.drop(['EmployeeCount','Over18', 'StandardHours', 'EmployeeID'], axis = 1)

# %%
df2
# Out:
#       Age  Attrition     BusinessTravel              Department  \
# 0      51          0      Travel_Rarely                   Sales
# 1      31          1  Travel_Frequently  Research & Development
# 2      32          0  Travel_Frequently  Research & Development
# 3      38          0         Non-Travel  Research & Development
# 4      32          0      Travel_Rarely  Research & Development
# ...   ...        ...                ...                     ...
# 4405   42          0      Travel_Rarely  Research & Development
# 4406   29          0      Travel_Rarely  Research & Development
# 4407   25          0      Travel_Rarely  Research & Development
# 4408   42          0      Travel_Rarely                   Sales
# 4409   40          0      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  Gender  JobLevel  \
# 0                    6          2  Life Sciences  Female         1
# ...

# %%
plt.figure(figsize= (20,20), dpi=200)
sns.heatmap(df2.corr(), annot=True, cmap="YlGnBu")

# %%
#These fields does not add value, hence removed
df= df1.drop(['EmployeeCount','Over18', 'StandardHours', 'EmployeeID'], axis = 1)

# %%
plt.figure(figsize= (20,20), dpi=200)
sns.heatmap(df.corr(), annot=True, cmap="YlGnBu")

# %%
df.Attrition.value_counts().plot(kind='pie', autopct = "%1.0f%%")

# %%
print(int(711*100/3699), '% is the attrition rate recorded.')
# Out:
# 19 % is the attrition rate recorded.

# %%
sns.countplot(hue= "Attrition",x ="BusinessTravel",data=df)

# %%
df2[["Attrition","BusinessTravel"]].groupby(['BusinessTravel'], 
                                             as_index=False).mean().sort_values(by='Attrition', ascending=False)
# Out:
#       BusinessTravel  Attrition
# 1  Travel_Frequently   0.249097
# 2      Travel_Rarely   0.149569
# 0         Non-Travel   0.080000

# %%
sns.countplot(x ="Attrition",hue ="EducationField",data=df2)

# %%
df2[["Attrition","EducationField"]].groupby(['EducationField'], 
                                             as_index=False).mean().sort_values(by='Attrition', ascending=False)
# Out:
#      EducationField  Attrition
# 0   Human Resources   0.407407
# 1     Life Sciences   0.166667
# 3           Medical   0.161638
# 2         Marketing   0.157233
# 4             Other   0.121951
# 5  Technical Degree   0.113636

# %%
sns.boxplot(x='Attrition', y='TotalWorkingYears', data=df2)

# %%
sns.countplot(x='Department', hue='Attrition', data=df2)

# %%
plt.figure(figsize= (20,5), dpi=100)
sns.countplot(x='YearsWithCurrManager', hue='Attrition', data=df2)

# %% [markdown]
# ### Employees with less than a year of work experience with the current manager left early. This might point to their bad performance.

# %%
plt.figure(figsize= (20,5), dpi=100)
sns.countplot(x='NumCompaniesWorked', hue='Attrition', data=df2)

# %%
plt.figure(figsize= (20,5), dpi=100)
sns.countplot(x ='TotalWorkingYears', hue ='Attrition', data=df2)

# %%
g = sns.FacetGrid(df, col='Attrition')
g.map(plt.hist, 'Age', bins=20)

# %%
'''Hypothesis 
H0 = Attrition and Distance from Home have no correlation.
Ha = Attrition and Distance from Home have correlation.'''
stats,p = pearsonr(df2.Attrition, df2.DistanceFromHome)
print("r= ", stats, " & p= ", p)
# Out:
# r=  -0.009730141010179692  & p=  0.5182860428050771

# %%
'''Hypothesis 
H0 = Attrition and StockOptionLevel have no correlation.
Ha = Attrition and StockOptionLevel have correlation.'''
stats,p = pearsonr(df2.Attrition, df2.StockOptionLevel)
print("r= ", stats, " & p= ", p)
# Out:
# r=  -0.006838852403261556  & p=  0.6498072937475723

# %% [markdown]
# ### p value being > 0.05 makes us accept our null hypotheses, H0.¶

# %% [markdown]
# ### Hence, there is no correlation between attrition and stock option level

# %%
'''Hypothesis 
H0 = Attrition and Training last year have no correlation.
Ha = Attrition and Tranining last year have correlation.'''
stats,p = pearsonr(df2.Attrition, df2.TrainingTimesLastYear)
print("r= ", stats, " & p= ", p)
# Out:
# r=  -0.04943057624425508  & p=  0.0010247061915362814

# %% [raw]
# As r is negative,hence there could exists a negative relationship between attrition and number of training last year.¶
#
# Further, p value being < 0.05 makes us reject our null hypotheses, H0.
#
# Hence, there is a negative correlation between attrition and number of training last year.####

# %%
'''Hypothesis 
H0 = Attrition and Gender have no correlation.
Ha = Attrition and Gender have correlation.'''
stats,p = pearsonr(df2.Attrition, df3.Gender)
print("r= ", stats, " & p= ", p)
# Out:
# r=  0.018125078877010186  & p=  0.22881970951795952

# %% [markdown]
# p value being > 0.05 makes us accept our null hypotheses, H0.
# Hence, there is no correlation between attrition and gender

# %%
'''Hypothesis 
H0 = Attrition and Monthly Income have no correlation.
Ha = Attrition and Monthly Income have correlation.'''
stats,p = pearsonr(df2.Attrition, df2.MonthlyIncome)
print("r= ", stats, " & p= ", p)
# Out:
# r=  -0.031176281698115087  & p=  0.03842748490600132

# %% [markdown]
# p value being < 0.05 makes us accept our null hypotheses, H0.
# Hence, there is a negative correlation between attrition and monthly income

# %% [markdown]
# # Parametric Tests
#
# ##Sample Independent t test :
#
# H0 : Age sample means has no significant diffrence from Year WithCurrManager mean between attrition and non-attrition data frames
# H1 : Age sample means has significant diffrence Year WithCurrManager mean between attrition and non-attrition data frames

# %%
Att_yes= df[df2['Attrition']== 1]
Att_yes
# Out:
#       Age  Attrition     BusinessTravel              Department  \
# 1      31          1  Travel_Frequently  Research & Development
# 6      28          1      Travel_Rarely  Research & Development
# 13     47          1         Non-Travel  Research & Development
# 28     44          1  Travel_Frequently  Research & Development
# 30     26          1      Travel_Rarely  Research & Development
# ...   ...        ...                ...                     ...
# 4381   29          1      Travel_Rarely  Research & Development
# 4386   33          1      Travel_Rarely                   Sales
# 4388   33          1      Travel_Rarely                   Sales
# 4391   32          1      Travel_Rarely                   Sales
# 4402   37          1  Travel_Frequently                   Sales
#
#       DistanceFromHome  Education EducationField  Gender  JobLevel  \
# 1                   10          1  Life Sciences  Female         1
# ...

# %%
Att_not= df[df2['Attrition']== 0]
Att_not
# Out:
#       Age  Attrition     BusinessTravel              Department  \
# 0      51          0      Travel_Rarely                   Sales
# 2      32          0  Travel_Frequently  Research & Development
# 3      38          0         Non-Travel  Research & Development
# 4      32          0      Travel_Rarely  Research & Development
# 5      46          0      Travel_Rarely  Research & Development
# ...   ...        ...                ...                     ...
# 4404   29          0      Travel_Rarely                   Sales
# 4405   42          0      Travel_Rarely  Research & Development
# 4406   29          0      Travel_Rarely  Research & Development
# 4407   25          0      Travel_Rarely  Research & Development
# 4408   42          0      Travel_Rarely                   Sales
#
#       DistanceFromHome  Education EducationField  Gender  JobLevel  \
# 0                    6          2  Life Sciences  Female         1
# ...

# %%
from scipy.stats import ttest_ind
stats, p = ttest_ind(Att_yes.YearsAtCompany, Att_not.YearsAtCompany)
print(f'The Value of p in t test is: {p}')
if p < 0.05:
    print('There is significant impact')
else:
    print('There is no significant impact')
# Out:
# The Value of p in t test is: 9.476118084889976e-19
# There is significant impact

# %% [markdown]
# H0 : Age sample means has no significance differences in YearsWithCurrManager mean between attrition and non-attrition data frames H1 : Age sample means has significant impact of YearsWithCurrManage

# %%
stats, p = ttest_ind(Att_yes.YearsWithCurrManager, Att_not.YearsWithCurrManager)
print(f'The Value of p in t test is: {p}')
if p < 0.05:
    print('There is significant impact')
else:
    print('There is no significant impact')
# Out:
# The Value of p in t test is: 7.105369646808081e-25
# There is significant impact

# %%
'''H0 : Age sample means has no significance differences in MonthlyIncome mean between attrition and non-attrition data frames
H1 : Age sample means has significant differences in MonthlyIncome mean between attrition and non-attrition data frames'''
from scipy.stats import ttest_ind
stats, p = ttest_ind(Att_yes.MonthlyIncome, Att_not.MonthlyIncome)
print(f'The Value of p in t test is: {p}')
if p < 0.05:
    print('There is significant impact')
else:
    print('There is no significant impact')
# Out:
# The Value of p in t test is: 0.0458908627449721
# There is significant impact

# %%
'''H0 : Age sample means has no significanct differences in the DistanceFromHome mean between attrition and non-attrition data frames
H1 : Age sample means has significanct differences in the DistanceFromHome mean between attrition and non-attrition data frames'''
from scipy.stats import ttest_ind
stats, p = ttest_ind(Att_yes.DistanceFromHome, Att_not.DistanceFromHome)
print(f'The Value of p in t test is: {p}')
if p < 0.05:
    print('There is significant impact')
else:
    print('There is no significant impact')
# Out:
# The Value of p in t test is: 0.5317715668047676
# There is no significant impact

# %% [markdown]
# ## Non-Parametric Tests¶
# ##Since no paired features are present we cannot do Wilcoxon Test and Freidman Test.
# Chi-Square Test

# %%
#Chi-Squared test 
#Gender and Attrition
crosstable1 = pd.crosstab(df.Attrition,df.Gender)
crosstable1
# Out:
# Gender     Female  Male
# Attrition
# 0            1488  2189
# 1             268   437

# %%
stats, p, dof, expected = chi2_contingency(crosstable1)
print(f'The Value of p in chi2_contingency test is: {p}')
if p < 0.05:
    print('Gender impacts Attrition')
else:
    print('Gender doesn\'t impact Attrition')
# Out:
# The Value of p in chi2_contingency test is: 0.24529482862926827
# Gender doesn't impact Attrition

# %%
crosstable2 = pd.crosstab(df.Attrition,df.Department)
crosstable2
# Out:
# Department  Human Resources  Research & Development  Sales
# Attrition
# 0                       132                    2416   1129
# 1                        55                     449    201

# %%
stats, p, dof, expected = chi2_contingency(crosstable1)
print(f'The Value of p in chi2_contingency test is: {p}')
if p < 0.05:
    print('Department impacts Attrition')
else:
    print('Department doesn\'t impact Attrition_')
# Out:
# The Value of p in chi2_contingency test is: 0.24529482862926827
# Department doesn't impact Attrition_

# %%
#Chi-Squared test 
#Marital Status and Attrition
crosstable3 = pd.crosstab(df.Attrition,df.MaritalStatus)
crosstable3
# Out:
# MaritalStatus  Divorced  Married  Single
# Attrition
# 0                   872     1756    1049
# 1                    98      251     356

# %%
print(f'The Value of p in chi2_contingency test is: {p}')
if p < 0.05:
    print('Marital Status impacts Attrition')
else:
    print('Marital Status doesn\'t impact Attrition_')
# Out:
# The Value of p in chi2_contingency test is: 0.24529482862926827
# Marital Status doesn't impact Attrition_

# %% [markdown]
# ## Mann Whitney U Test

# %%
stats, p = mannwhitneyu(Att_yes.DistanceFromHome, Att_not.DistanceFromHome)
print(f'The Value of p in mannwhitneyu test is: {p}')
if p < 0.05:
    print('There is significant impact')
else:
    print('There is no significant impact')
# Out:
# The Value of p in mannwhitneyu test is: 0.488538986087403
# There is no significant impact

# %%
stats, p = mannwhitneyu(Att_yes.YearsAtCompany, Att_not.YearsAtCompany)
print(f'The Value of p in mannwhitneyu test is: {p}')
if p < 0.05:
    print('There is significant impact')
else:
    print('There is no significant impact')
# Out:
# The Value of p in mannwhitneyu test is: 3.3433144809752036e-36
# There is significant impact

# %%
stats, p = mannwhitneyu(Att_yes.YearsAtCompany, Att_not.StockOptionLevel)
print(f'The Value of p in mannwhitneyu test is: {p}')
if p < 0.05:
    print('There is significant impact')
else:
    print('There is no significant impact')
# Out:
# The Value of p in mannwhitneyu test is: 2.3656462927471587e-202
# There is significant impact

# %%
def generate_frequency_graph(col_name):
    
    # Plotting of Employee Attrition against feature
    temp_grp = df2.groupby(col_name).agg('sum')[['Attrition_Yes', 'Attrition_No']]
    temp_grp['Percentage Attrition'] =  temp_grp['Attrition_Yes'] / (temp_grp['Attrition_Yes'] + temp_grp['Attrition_No']) * 100
    print(temp_grp)
    df2.groupby(col_name).agg('sum')[['Attrition_Yes', 'Attrition_No']].plot(kind='bar', stacked=False, color=['red', 'green'])
    plt.xlabel('BusinessTravel')
    plt.ylabel('Attrition');

# %% [markdown]
# Insights:
# 1. Single employees leaves the XYZ company more often.
# 2. Employees who are made to travel frequently leaves the XYZ company more often.
# 3. Educational background in Human Resources tends to leave XYZ company more often.
# 4. Employee in Human Resources department tends to leave XYZ company more often, also same can be inferred from point 3 as well.
# 5. Employees who have less number of total working years or experience leaves the current company more often. Also, on the other end, experienced/oldest employees are seeking stability.
# 6. Younger and 0 to 1 YearsWithCurrManager employees tend to leave the XYZ company more often.
# 7. Strong negative correlation exist for YearsAtCompany which means that employees who have spent less number of years in company leaves the company more often.
